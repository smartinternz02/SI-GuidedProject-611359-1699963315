# %%
#importing libraries required
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import dataset
data=pd.read_csv("d://Predicting  Mental illness/Data//survey.csv")

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data.tail()
# Out:
#                 Timestamp  Age Gender         Country state self_employed  \
# 1254  2015-09-12 11:17:21   26   male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32   Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34   male   United States    CA            No
# 1257  2015-11-30 21:25:06   46      f   United States    NC            No
# 1258  2016-02-01 23:04:31   25   Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# 1254             No       Yes            NaN          26-100  ...
# 1255            Yes       Yes          Often          26-100  ...
# 1256            Yes       Yes      Sometimes  More than 1000  ...
# 1257             No        No            NaN         100-500  ...
# 1258            Yes       Yes      Sometimes          26-100  ...
#
#                    leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data.shape
# Out:
# (1259, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %% [markdown]
# # Data preprocessing

# %% [raw]
# Time stamps and the comments are not useful for our analysis.
# So the timestamp and comments columns are removed as they do not contribute to providing relevant
# information.

# %%
data.drop(['Timestamp','comments'] ,axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age  Gender         Country state self_employed family_history treatment  \
# 0   37  Female   United States    IL           NaN             No       Yes
# 1   44       M   United States    IN           NaN             No        No
# 2   32    Male          Canada   NaN           NaN             No        No
# 3   31    Male  United Kingdom   NaN           NaN            Yes       Yes
# 4   31    Male   United States    TX           NaN             No        No
#
#   work_interfere    no_employees remote_work  ...   anonymity  \
# 0          Often            6-25          No  ...         Yes
# 1         Rarely  More than 1000          No  ...  Don't know
# 2         Rarely            6-25          No  ...  Don't know
# 3          Often          26-100          No  ...          No
# 4          Never         100-500         Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
data['Country'].value_counts().plot(kind='bar',figsize=(10,8))
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Counts of Each Country')
plt.show()

# %%
# Assuming data is your DataFrame or dataset
data['state'].value_counts().plot(kind='bar', figsize=(10, 8))
plt.xlabel('State')
plt.ylabel('Count')
plt.title('Counts of Each State')
plt.show()

# %% [raw]
# Since the countries are not evenly distributed, keeping this column will induce bias in
# our model.
# so these columns are removed

# %%
data.drop(['Country','state'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Age  Gender self_employed family_history treatment work_interfere  \
# 0   37  Female           NaN             No       Yes          Often
# 1   44       M           NaN             No        No         Rarely
# 2   32    Male           NaN             No        No         Rarely
# 3   31    Male           NaN            Yes       Yes          Often
# 4   31    Male           NaN             No        No          Never
#
#      no_employees remote_work tech_company    benefits  ...   anonymity  \
# 0            6-25          No          Yes         Yes  ...         Yes
# 1  More than 1000          No           No  Don't know  ...  Don't know
# 2            6-25          No          Yes          No  ...  Don't know
# 3          26-100          No          Yes          No  ...          No
# 4         100-500         Yes          Yes         Yes  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %% [markdown]
# # Checking null values

# %%
data.isnull().sum()
# Out:
# Age                            0
# Gender                         0
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
data['self_employed'].mode()
# Out:
# 0    No
# Name: self_employed, dtype: object

# %%
data['work_interfere'].mode()
# Out:
# 0    Sometimes
# Name: work_interfere, dtype: object

# %%
data['work_interfere'].fillna('N/A', inplace=True)
data['self_employed'].fillna('No', inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %% [raw]
# Checking for wrongly entered or outliers

# %%
data['Age'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
#so only keeping the rows with the age between 18 and 60
data.drop(data[(data['Age']>60)| (data['Age']<18)].index,inplace=True)

# %%
data['Gender'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %% [raw]
# It is observed that different names are used for the same category of gender. Let us group
# them into 3 major categories- Male, Female and Non-Binary using the .replace() function.

# %%
data['Gender'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
data['Gender'].values
# Out:
# array(['Female', 'M', 'Male', ..., 'male', 'f', 'Male'], dtype=object)

# %%
data['Gender'].replace([ 'Male','Male ', 'male', 'M', 'm', 'Male', 'Cis Male', 'Man', 'cis male', 'Mail', 'Male-ish', 'Male (CIS)', 'Cis Man', 'msle', 'Malr', 'Mal', 'maile', 'Make', ], 'Male', inplace=True)
data['Gender'].replace(['Female','Female ', 'female', 'F', 'f', 'Woman', 'Female', 'femail', 'Cis Female', 'cis-female/femme', 'Femake', 'Female (cis)', 'woman', ], 'Female', inplace=True)
data["Gender"].replace(['Female (trans)', 'queer/she/they', 'non-binary',
'fluid', 'queer','Guy (-ish) ^_^', 'Androgyne', 'Trans-female', 'male leaning androgynous', 'Agender', 'A little about you', 'Nah', 'All', 'ostensibly male, unsure what that really means', 'Genderqueer', 'Enby', 'p', 'Neuter', 'something kinda male?', 'Guy (-ish) ^^', 'Trans woman', ], 'Non-Binary', inplace = True)

# %%
data['Gender'].value_counts()
# Out:
# Male          983
# Female        246
# Non-Binary     18
# Name: Gender, dtype: int64

# %%
data['Gender'].value_counts().plot(kind='bar',figsize=(10,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data analysis and visualisation

# %% [raw]
# Univariate analysis

# %%
sns.displot(data['Age'], kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %% [raw]
# Bivariate analysis

# %% [raw]
# We use bivariate analysis to find the relation between two features. Here we are visualising
# the relationship of various features with respect to treatment, which is our target variable.

# %%
plt.figure(figsize=(4, 2))
sns.countplot(data=data, x='self_employed', hue='treatment')
plt.title(' Treatment and self_employed')
plt.show()

# %% [raw]
# We observe that though there is a vast difference between people who are self
# employed or not, the number of people who seek treatment in both the categories is
# more or less similar.

# %%
plt.figure(figsize=(4, 2))
sns.countplot(data=data, x='family_history', hue='treatment')
plt.title('Treatment and family_history')
plt.show()

# %% [raw]
# We observe that treatment is directly proportional to family history. Hence this is an
# important factor.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='work_interfere', hue='treatment')
plt.title('treatment and work_interfere')
plt.show()

# %% [raw]
# We observe that the people who chose Sometimes were the largest who wanted to get
# treatment. These group of people are the ones who are reluctant to choose either of
# the extreme categories.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='remote_work', hue='treatment')
plt.title('Treatment and Remote Work')
plt.show()

# %% [raw]
# We observe that the number of people who seek treatment in both the categories is
# more or less similar and it does not affect our target variable.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='tech_company', hue='treatment')
plt.title(' Treatment and tech_company')
plt.show()

# %% [raw]
# We can conclude that irrespective of the field the company of the people falls in,
# mental health is a big issue.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='benefits', hue='treatment')
plt.title('Treatment and benefits')
plt.show()

# %% [raw]
# We see that a large group among the people who wanted mental health benefits
# wanted to seek treatment and also a significant number of people who said No too,
# wanted to seek treatment.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='care_options', hue='treatment')
plt.title('Treatment and care_options')
plt.show()

# %% [raw]
# This graph is quite similar to the benefits column.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='mental_vs_physical', hue='treatment')
plt.title(' Treatment and mental_vs_physical ')
plt.show()

# %% [raw]
# We observe that half of the people are not aware of the importance given to mental
# health as compared to physical health, whereas almost equal parts of the other halves
# answered Yes and No.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='wellness_program', hue='treatment')
plt.title('Treatment and wellness_program ')
plt.show()

# %% [raw]
# We observe that almost half of the people who said No want to seek treatment, which
# means their company has to take steps in arranging for the same.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='anonymity', hue='treatment')
plt.title('Treatment and anonymity')
plt.show()

# %% [raw]
# We observe that most people either answered yes or they are not aware if their
# anonymity will be protected.

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='leave', hue='treatment')
plt.title(' Treatment and leave ')
plt.show()

# %% [raw]
# We see that around half of the total people don’t know how easy it is to get a leave
# due to a mental health condition and they are the ones who want to seek treatment the
# most.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='mental_health_consequence', hue='treatment')
plt.title('Mental health consequence and treatment')
plt.show()

# %% [raw]
# We observe that the majority answered either No or Maybe but around 1/3rd of the
# people answered yes and they want to seek treatment.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='phys_health_consequence', hue='treatment')
plt.title('Physical health consequence and treatment')
plt.show()

# %% [raw]
# As completely opposed to the above results, a very small number of people answered
# yes to this question, which means that a major number of people do not face negative
# consequences by discussing their physical health conditions with their employers.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='coworkers', hue='treatment')
plt.title('Discussion with coworkers and treatment')
plt.show()

# %% [raw]
# We can observe that more than half of the people were willing to discuss their mental
# health problems with some or all of their coworkers.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='supervisor', hue='treatment')
plt.title('Discussion with supervisor and treatment')
plt.show()

# %% [raw]
# This graph again, is in contrast to the above one. Though majority of people are
# comfortable with discussing their physical health problems with their supervisor,
# about 1/3rd of them aren’t comfortable with it.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='mental_health_interview', hue='treatment')
plt.title('Mental health discussion during interview and treatment')
plt.show()

# %% [raw]
# We observe that very few people are comfortable in bringing up their mental health
# issue in front of a potential employer.

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='mental_health_interview', hue='treatment')
plt.title('Mental health discussion during interview and treatment')
plt.show()
